# %%
import pandas as pd

# %%
train_x = pd.read_csv("./mod_Data/train_x_remove_ver1.csv")
val_x = pd.read_csv("./mod_Data/val_x_remove_ver1.csv")
val_y = pd.read_csv("./mod_Data/val_y_remove_ver1.csv")

# %%
val_x.head(3)
# Out:
#          V2        V3        V6        V7        V9       V10       V11  \
# 0  1.119593  1.044367 -0.246761  0.651583 -0.736727 -0.366846  1.017614
# 1  0.328461 -0.171479  1.696038  0.107712 -1.191311  0.724396  1.690330
# 2  0.575068  0.194008 -1.044430  0.531588 -0.896287  0.757952 -0.448937
#
#         V12       V13       V14       V15       V16       V17       V18  \
# 0  0.836390  1.006844 -0.443523  0.150219  0.739453 -0.540980  0.476677
# 1  0.406774 -0.936421  0.983739  0.710911 -0.602232  0.402484 -1.737162
# 2 -0.660863 -1.308522  0.788864  0.320294  0.295404 -0.287878 -0.451453
#
#         V19       V20       V23       V24       V25       V28
# 0  0.451773  0.203711 -0.120794 -0.385050 -0.069733  0.083076
# 1 -2.027612 -0.269321 -0.048508 -1.371866  0.390814 -0.014605
# 2 -1.011446 -0.191050 -0.076510  0.691320  0.633984  0.016251

# %%
val_df = pd.concat([val_x,val_y],axis=1)

# %%
val_df.tail(33)
# Out:
#              V2        V3        V6        V7        V9       V10       V11  \
# 28429 -3.380753 -3.890511 -0.822619  1.514705 -0.901784  0.565653 -1.635506
# 28430  1.913438  0.005864  0.395466 -0.075044  0.043086  0.296319  0.922980
# 28431 -1.646802  0.437724 -0.438380  0.888150  0.272534 -1.948570  0.112596
# 28432  0.745141 -0.224252 -0.741998  1.384378 -0.500626 -0.611905 -1.412511
# 28433  2.936499 -2.579211 -1.317064  0.399466  0.079735  0.982259  0.440093
# 28434  1.477627  0.394490  0.088881  1.177707 -1.820574  0.852848 -1.647761
# 28435  0.763164  0.185440 -0.824899  0.837716  0.751164 -0.018101 -1.282571
# 28436 -0.041528 -1.492927 -0.584289  0.266498  0.426756  0.031565 -1.463225
# 28437  0.104764 -1.804835 -0.385076  0.081787  0.242933 -0.211236  0.879270
# 28438  1.549750 -1.085567 -0.293383  1.493051  0.051545  0.284886 -0.000446
# 28439 -2.408392 -1.458041 -1.509535  1.160473 -0.062457  0.815249  1.044106
# ...

# %%
val_df
# Out:
#              V2        V3        V6        V7        V9       V10       V11  \
# 0      1.119593  1.044367 -0.246761  0.651583 -0.736727 -0.366846  1.017614
# 1      0.328461 -0.171479  1.696038  0.107712 -1.191311  0.724396  1.690330
# 2      0.575068  0.194008 -1.044430  0.531588 -0.896287  0.757952 -0.448937
# 3     -0.323684  0.387585  1.650358 -0.427576  0.226278 -0.225495  1.944545
# 4      2.600138  1.483691 -0.824575  2.065426  4.009259  6.051521  2.572500
# ...         ...       ...       ...       ...       ...       ...       ...
# 28457  1.433992 -0.313252 -0.565669  1.066075 -1.099446 -0.077753  0.534689
# 28458  0.588379 -0.907599 -0.760802  0.758545 -0.730854 -1.245088  0.874312
# 28459  1.302212 -0.168583 -0.605641  1.253430 -0.417116  0.076605 -1.291228
# 28460 -0.175233 -1.196825 -0.726571  0.017050  0.435402  0.267772  0.523316
# 28461  0.530483  0.702510  0.623708 -0.686180  0.392087 -0.399126 -1.933849
#
# ...

# %%
import seaborn as sns
x = 7

sns.pairplot(
    data=val_df,
    x_vars= [val_df.columns[x]],
    y_vars=list(val_df.columns),
    hue = 'Class'
)
